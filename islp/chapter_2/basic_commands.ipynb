# %%
print('fit a model with ', 11, ' variables')
# Out:
# fit a model with  11  variables

# %%
x = 11
print(f'fit a model with {x} variables')
# Out:
# fit a model with 11 variables

# %%
"hello" + " world"
# Out:
# 'hello world'

# %%
x = [1, 2, 3]
x
# Out:
# [1, 2, 3]

# %%
y = [4, 5, 6]
y
# Out:
# [4, 5, 6]

# %%
x + y
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
z = [i for i in x + y]
z
# Out:
# [1, 2, 3, 4, 5, 6]
