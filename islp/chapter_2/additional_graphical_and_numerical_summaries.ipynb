# %% [markdown]
# # 2.3.9 Additional Graphical and Numerical Summaries

# %%
import pandas as pd
import numpy as np
from matplotlib.pyplot import subplots

# %%
DATASET_PATH = '../datasets/'

# %%
data_path = DATASET_PATH + 'Auto.data'

Auto = pd.read_csv(data_path,
                   na_values=['?'],
                   delim_whitespace=True)

Auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0  3504.0          12.0    70
# 1    15.0          8         350.0       165.0  3693.0          11.5    70
# 2    18.0          8         318.0       150.0  3436.0          11.0    70
# 3    16.0          8         304.0       150.0  3433.0          12.0    70
# 4    17.0          8         302.0       140.0  3449.0          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0  2790.0          15.6    82
# 393  44.0          4          97.0        52.0  2130.0          24.6    82
# 394  32.0          4         135.0        84.0  2295.0          11.6    82
# 395  28.0          4         120.0        79.0  2625.0          18.6    82
# 396  31.0          4         119.0        82.0  2720.0          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 392       1            ford mustang gl
# 393       2                  vw pickup
# 394       1              dodge rampage
# 395       1                ford ranger
# 396       1                 chevy s-10
#
# [397 rows x 9 columns]

# %%
fig, ax = subplots(figsize=(8,8))
ax.plot(horsepower, mpg, 'o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 fig, ax = subplots(figsize=(8,8))
# ----> 2 ax.plot(horsepower, mpg, 'o')
#
# NameError: name 'horsepower' is not defined

# %%
fig, ax = subplots(figsize=(8,8))
ax.plot(Auto['horsepower'], Auto['mpg'], 'o');

# %%
ax = Auto.plot.scatter(x='horsepower', y='mpg')
ax.set_title('Horsepower vs. MPG')
# Out:
# Text(0.5, 1.0, 'Horsepower vs. MPG')

# %%
fig, axes = subplots(ncols=3, figsize=(15,5))
Auto.plot.scatter('horsepower', 'mpg', ax=axes[1])
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
Auto.cylinder = pd.Series(Auto.cylinders, dtype='category')
Auto.cylinders.dtype
# Out:
# /tmp/ipykernel_20568/493809676.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Auto.cylinder = pd.Series(Auto.cylinders, dtype='category')
# dtype('int64')

# %%
fig, ax = subplots(figsize=(8,8))
Auto.boxplot('mpg', by='cylinders', ax=ax)
# Out:
# <Axes: title={'center': 'mpg'}, xlabel='cylinders'>

# %%
fig, ax = subplots(figsize=(8,8))
Auto.hist('mpg', ax=ax)
# Out:
# array([<Axes: title={'center': 'mpg'}>], dtype=object)

# %%
pd.plotting.scatter_matrix(Auto, figsize=(10,10));

# %%
Auto[['mpg', 'horsepower', 'weight']].describe()
# Out:
#               mpg  horsepower       weight
# count  397.000000  392.000000   397.000000
# mean    23.515869  104.469388  2970.261965
# std      7.825804   38.491160   847.904119
# min      9.000000   46.000000  1613.000000
# 25%     17.500000   75.000000  2223.000000
# 50%     23.000000   93.500000  2800.000000
# 75%     29.000000  126.000000  3609.000000
# max     46.600000  230.000000  5140.000000
